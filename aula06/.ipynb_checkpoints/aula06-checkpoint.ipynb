# %%
#Pilhas

Class_Stack:

def __init__(self):
     self.itens = []

def __init__ (self):
    return self.itens == []

def push (self, item):
    self.itens.append (item)
    print (f' {item} inserido!')

def pop(self):
   return self.itens.pop ()

def peek (self):
    return self.itens [-1]

def size (self):
    return len (self.itens)

def print (self):
    print (self.itens)

# %%
#Conversão de decimal para binário


def decimal_para_binario (x):
    s = stack()
    while x > 0:
        q = x // 2
        r = x % 2
        s.push(r)
        x = q

    resultado = ""
    while not s.is_empty ():
        resultado = resultado + str (s.pop() )
    return resultado
    
print(decimal_para_binario(412))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 31
#      27     while not s.is_empty ():
#      28         resultado = resultado + str (s.pop() )
#      29     return resultado
#      30
# ---> 31 print(decimal_para_binario(412))
#
# Cell In[8], line 19, in decimal_para_binario(x)
#      18 def decimal_para_binario (x):
# ---> 19     s = stack()
#      20     while x > 0:
#      21         q = x // 2
#      22         r = x % 2
#
# NameError: name 'stack' is not defined
