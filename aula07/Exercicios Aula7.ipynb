# %%
def batata_quente (nomes, qtd_passadas):
    crianças = Queue()

    #Popular a fila
    for nome in nomes:
        crianças.enqueue(nome)

    #Repetir ate restar um
    while crianças.size() > 1:

        #Faz a rodada
        for _ in range (qtd_passadas):
            pessoa = criança.dequeue()
            criança.enqueue(pessoa)

        eliminado = criança.dequeue()
        print(f'Você foi eliminado!')

    Vencedor = criança.dequeue()


    return ganhador

# %%
Jogadores = ['Ana', 'Leticia', 'Joana', 'Rafaela', 'Tania', 'João']
ganhador = batata_quente (jogadores, 29)
print(f'O ganhador foi (ganhador)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 Jogadores = ['Ana', 'Leticia', 'Joana', 'Rafaela', 'Tania', 'João']
# ----> 2 ganhador = batata_quente (jogadores, 29)
#       3 print(f'O ganhador foi (ganhador)')
#
# NameError: name 'jogadores' is not defined
